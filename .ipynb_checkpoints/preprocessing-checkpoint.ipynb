# %%
filename="Gerasimov FAA"
filename_csv=filename+".csv"
#correct the csv file generated by swing by comparing to the score
lst_players=filename_csv.split(".")[0].split(" ")
name1=lst_players[0]
name2=lst_players[1]
#set the time just before the first serve played
start=6*60+0

# %%
#COPY the 2nd sheet fo the xlsx file to a proper CSV file
import openpyxl
import csv
import pandas as pd
  
# open given workbook 
# and store in excel object 
wb = openpyxl.load_workbook(filename+".xlsx")
sheets = wb.sheetnames
sheet = wb[sheets[1]]  
  
    
with open(filename_csv, 'w',newline="") as outfile:
    writer = csv.writer(outfile)
    # writing the data in csv file
    for r in sheet.rows:
        # row by row write 
        # operation is perform
        writer.writerow([cell.value for cell in r])

# read the csv file and 
# convert into dataframe object 
df = pd.DataFrame(pd.read_csv(filename+".csv",index_col=False))
  
# show the dataframe
df#.columns
# Out:
#        Player  Shot   Type    Stroke     Spin  Speed (KM/H)  Point  Game  Set  \
# 0    Opponent     0   none      Feed     Flat     34.843319      1     0    0
# 1    Opponent     1   none  Backhand  Topspin     94.824356      1     0    0
# 2    Opponent     0   none  Backhand  Topspin    111.631989      2     0    0
# 3      Player     0   none  Forehand     Flat     54.031391      3     0    0
# 4    Opponent     1   none  Backhand  Topspin     95.357994      3     0    0
# ..        ...   ...    ...       ...      ...           ...    ...   ...  ...
# 790  Opponent     0   none  Forehand  Topspin     95.143509    291     0    0
# 791  Opponent     0   none  Forehand  Topspin     97.738365    292     0    0
# 792  Opponent     0   none  Forehand     Flat     59.091869    293     0    0
# 793    Player     0   none  Forehand  Topspin     78.887520    294     0    0
# 794    Player     1  serve     Serve    Slice    102.705185    295     0    0
#
#      Bounce Depth  ...   Hit Zone Hit Side    Hit (x)    Hit (y)    Hit (z)  \
# 0     service_box  ...      deuce      far  -0.654909  13.292222   1.376143
# 1    no_mans_land  ...         ad      far   0.594692  17.566118   1.993547
# 2     service_box  ...  deuce_out      far -10.134499  34.701275  12.571716
# 3    no_mans_land  ...      deuce     near   0.738696  11.294303   3.625444
# 4     service_box  ...         ad      far   0.337167  19.692194   1.279645
# ..            ...  ...        ...      ...        ...        ...        ...
# 790  no_mans_land  ...      deuce     near   0.525265   0.819096   1.354904
# 791  no_mans_land  ...      deuce     near   1.793506   1.243724   1.953281
# 792   service_box  ...      deuce     near   0.735498  -1.232222   1.901489
# 793   service_box  ...      deuce     near   1.653944  11.218221   1.952657
# 794   service_box  ...         ad     near  -0.334835   0.495653   2.225255
#
#          Direction Result  Favorited  Start Time   Video Time
# 0              ---     In      False    14:06:36     5.680000
# 1      cross court    Net      False    14:06:39     8.180000
# 2        inside in     In      False    14:06:43    12.780000
# 3    down the line     In      False    14:06:50    19.080000
# 4      cross court     In      False    14:06:50    19.680000
# ..             ...    ...        ...         ...          ...
# 790  down the line     In      False    16:04:46  7095.379883
# 791  down the line    Net      False    16:04:57  7106.080078
# 792    cross court    Net      False    16:05:07  7116.919922
# 793    cross court    Net      False    16:05:33  7142.080078
# 794     down the T     In      False    16:05:40  7149.379883
#
# [795 rows x 25 columns]

# %%
def get_all_shots_for_point(df):
    return (df[df["Point"].astype(int)==int(point_index)]).sort_values(by='Shot')

# %%
#REMOVE WARM UP shots and reindex points at 1
import pandas as pd
import numpy as np

df=pd.read_csv(filename_csv, index_col=0)
df=df.dropna(subset=["Point"])

try:
    df["Speed (KM/H)"]=round(df["Speed (KM/H)"])
except:
    pass
#remove the warm up
df=df[df["Video Time"] > start]
#reset the point at 1 (so we don't count warmup points anymore)
first_point=df.iloc[0]["Point"]
print("Point1 was actually: "+str(first_point))

#readjust point indexes
df["Point"]=df["Point"]-first_point+1
try:
    df = df.drop("Unnamed: 0", axis=1)
except:
    pass
df.to_csv(filename_csv)
df=pd.read_csv(filename_csv)
print("Point1 is now : "+str(first_point))
df
# Out:
# Point1 was actually: 13
# Point1 is now : 13
#        Player  Shot            Type    Stroke     Spin  Speed (KM/H)  Point  \
# 0    Opponent     1           serve     Serve     Flat          77.0      1
# 1      Player     2          return  Forehand  Topspin          85.0      1
# 2    Opponent     3  serve_plus_one  Forehand  Topspin          57.0      1
# 3    Opponent     1           serve     Serve     Flat         137.0      2
# 4      Player     2          return  Forehand  Topspin          78.0      2
# ..        ...   ...             ...       ...      ...           ...    ...
# 768  Opponent     0            none  Forehand  Topspin          95.0    279
# 769  Opponent     0            none  Forehand  Topspin          98.0    280
# 770  Opponent     0            none  Forehand     Flat          59.0    281
# 771    Player     0            none  Forehand  Topspin          79.0    282
# 772    Player     1           serve     Serve    Slice         103.0    283
#
#      Game  Set  Bounce Depth  ...     Hit Zone Hit Side   Hit (x)    Hit (y)  \
# 0       0    0   service_box  ...        deuce      far -1.615303  24.513660
# 1       0    0  no_mans_land  ...  deuce_alley     near  4.312782  -0.572254
# 2       0    0           out  ...        deuce      far -0.588359  24.762449
# 3       0    0   service_box  ...           ad      far  1.005584  24.331457
# 4       0    0   service_box  ...           ad     near -2.920594  -1.357419
# ..    ...  ...           ...  ...          ...      ...       ...        ...
# 768     0    0  no_mans_land  ...        deuce     near  0.525265   0.819096
# 769     0    0  no_mans_land  ...        deuce     near  1.793506   1.243724
# 770     0    0   service_box  ...        deuce     near  0.735498  -1.232222
# 771     0    0   service_box  ...        deuce     near  1.653944  11.218221
# 772     0    0   service_box  ...           ad     near -0.334835   0.495653
#
#       Hit (z)      Direction Result  Favorited  Start Time   Video Time
# 0    2.726496       out wide     In      False    14:12:34   363.980011
# 1    0.942273  down the line     In      False    14:12:36   365.239990
# 2    1.248856  down the line    Out      False    14:12:37   366.359985
# 3    2.501394       out wide     In      False    14:12:56   385.579987
# 4    1.018629     inside out     In      False    14:12:57   386.440002
# ..        ...            ...    ...        ...         ...          ...
# 768  1.354904  down the line     In      False    16:04:46  7095.379883
# 769  1.953281  down the line    Net      False    16:04:57  7106.080078
# 770  1.901489    cross court    Net      False    16:05:07  7116.919922
# 771  1.952657    cross court    Net      False    16:05:33  7142.080078
# 772  2.225255     down the T     In      False    16:05:40  7149.379883
#
# [773 rows x 25 columns]

# %%
#REMOVE ALL SHOTS where shot=0 
def remove_allshots_where_0(df):
    print("df before:{0}".format(len(df)))
    df=df[df["Shot"]>0]
    print("df after:{0}".format(len(df)))
    df.rename(columns = {'Speed (KM/H)':'Speed'," Hit (x)":"hit_x"," Hit (y)":"hit_y"," Hit (z)":"hit_z"}, inplace = True)
    dfP1=df[df.Player=="Player"]
    print("dfP1:{0}".format(len(dfP1)))
    dfP2=df[df.Player=="Opponent"]
    print("dfP2:{0}".format(len(dfP2)))
#remove_allshots_where_0(df)

# %%
#set the winner of the point for every shot

def set_point_winner(df, point_index: int):
    """
    Returns
    1 if player1 won the point
    0 if player 2
    -1 if player 1 hit his serve out
    -2 if player 2 hit his serve out
    """
    df_all_shots_for_point = get_all_shots_for_point(df)
    df_last_shot = df_all_shots_for_point[df_all_shots_for_point["Shot"]==df_all_shots_for_point["Shot"].max()]
    last_shot_result = df_last_shot.iloc[0]["Result"]
    index_winner = -1
    str_player_last_shot = df_last_shot.iloc[0]["Player"]
    print(str_player_last_shot)
    if (df_last_shot.iloc[0]["Shot"]==1) and (last_shot_result in ["Out", "Net"]):
        if (str_player_last_shot == "Player"):
            if df_last_shot.iloc[0]["Type"]=="second_serve":
                index_winner = "0" #DF
            else:
                index_winner = "-1" #Player serve out or net
        else:
            if df_last_shot.iloc[0]["Type"]=="second_serve":
                index_winner = "1"#DF
            else:
                index_winner = "-2" #Opponent serve out or net
    elif (str_player_last_shot == "Player"):
        if (last_shot_result in ["In"]):
            index_winner = "1"
        elif (last_shot_result in ["Out", "Net"]):
            index_winner = "0"
        else:
            index_winner = "-1"
    elif (str_player_last_shot == "Opponent"):
        if (last_shot_result in ["In"]):
            index_winner = "0"
        elif (last_shot_result in ["Out", "Net"]):
            index_winner = "1"
        else:
            index_winner = "-1"
    else:
        index_winner = "-1"
    #print(str(index_winner))
    df.loc[df["Point"]==point_index,"Winner_Point"]=index_winner
    
#set_point_winner(df, 8)

# %%
#FOR EACH UNIQUE POINT, set point_winner for all shots of this point
for point_index in df["Point"].unique():
    set_point_winner(df, point_index)

#SAVE FILE
df.to_csv(filename_csv)
df
# Out:
# Opponent
# Player
# Player
# Opponent
# Opponent
# Player
# Opponent
# Player
# Opponent
# Opponent
# Player
# Player
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Player
# Opponent
# Player
# Opponent
# Opponent
# Opponent
# Player
# Opponent
# Opponent
# Player
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Player
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Player
# Player
# Opponent
# Player
# Player
# Player
# Player
# Opponent
# Opponent
# Player
# Opponent
# Player
# Opponent
# Opponent
# Player
# Opponent
# Player
# Opponent
# Opponent
# Opponent
# Player
# Player
# Opponent
# Opponent
# Opponent
# Player
# Opponent
# Player
# Player
# Opponent
# Player
# Opponent
# Opponent
# Opponent
# Opponent
# Player
# Player
# Opponent
# Player
# Opponent
# Player
# Opponent
# Opponent
# Player
# Player
# Opponent
# Player
# Opponent
# Opponent
# Player
# Player
# Player
# Player
# Player
# Opponent
# Opponent
# Player
# Player
# Player
# Player
# Opponent
# Player
# Opponent
# Opponent
# Opponent
# Opponent
# Player
# Player
# Opponent
# Opponent
# Player
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Player
# Player
# Opponent
# Player
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Opponent
# Player
# Player
# Player
# Player
# Player
# Player
# Opponent
# Opponent
# Opponent
# Player
# Opponent
# Opponent
# Player
# Opponent
# Player
# Player
# Player
# Player
# Player
# Player
# Opponent
# Opponent
# Player
# Opponent
# Player
# Opponent
# Player
# Player
# Opponent
# Opponent
# Opponent
# Opponent
# Player
# Player
# Opponent
# Player
# Player
# Opponent
# Player
# Opponent
# Opponent
# Opponent
# Opponent
# Player
# Player
# Player
# Player
# Player
# Opponent
# Opponent
# Opponent
# Player
# Opponent
# Player
# Player
# Opponent
# Opponent
# Opponent
# Player
# Player
#        Player  Shot            Type    Stroke     Spin  Speed (KM/H)  Point  \
# 0    Opponent     1           serve     Serve     Flat          77.0      1
# 1      Player     2          return  Forehand  Topspin          85.0      1
# 2    Opponent     3  serve_plus_one  Forehand  Topspin          57.0      1
# 3    Opponent     1           serve     Serve     Flat         137.0      2
# 4      Player     2          return  Forehand  Topspin          78.0      2
# ..        ...   ...             ...       ...      ...           ...    ...
# 768  Opponent     0            none  Forehand  Topspin          95.0    279
# 769  Opponent     0            none  Forehand  Topspin          98.0    280
# 770  Opponent     0            none  Forehand     Flat          59.0    281
# 771    Player     0            none  Forehand  Topspin          79.0    282
# 772    Player     1           serve     Serve    Slice         103.0    283
#
#      Game  Set  Bounce Depth  ... Hit Side   Hit (x)    Hit (y)   Hit (z)  \
# 0       0    0   service_box  ...      far -1.615303  24.513660  2.726496
# 1       0    0  no_mans_land  ...     near  4.312782  -0.572254  0.942273
# 2       0    0           out  ...      far -0.588359  24.762449  1.248856
# 3       0    0   service_box  ...      far  1.005584  24.331457  2.501394
# 4       0    0   service_box  ...     near -2.920594  -1.357419  1.018629
# ..    ...  ...           ...  ...      ...       ...        ...       ...
# 768     0    0  no_mans_land  ...     near  0.525265   0.819096  1.354904
# 769     0    0  no_mans_land  ...     near  1.793506   1.243724  1.953281
# 770     0    0   service_box  ...     near  0.735498  -1.232222  1.901489
# 771     0    0   service_box  ...     near  1.653944  11.218221  1.952657
# 772     0    0   service_box  ...     near -0.334835   0.495653  2.225255
#
#          Direction Result Favorited  Start Time   Video Time  Winner_Point
# 0         out wide     In     False    14:12:34   363.980011             1
# 1    down the line     In     False    14:12:36   365.239990             1
# 2    down the line    Out     False    14:12:37   366.359985             1
# 3         out wide     In     False    14:12:56   385.579987             0
# 4       inside out     In     False    14:12:57   386.440002             0
# ..             ...    ...       ...         ...          ...           ...
# 768  down the line     In     False    16:04:46  7095.379883             0
# 769  down the line    Net     False    16:04:57  7106.080078             1
# 770    cross court    Net     False    16:05:07  7116.919922             1
# 771    cross court    Net     False    16:05:33  7142.080078             0
# 772     down the T     In     False    16:05:40  7149.379883             1
#
# [773 rows x 26 columns]

# %%
print(name2 + " on SERVE, point winners:")
df[(df["Shot"]==1)&(df["Player"]=="Opponent")]["Winner_Point"].value_counts()
# Out:
# Schwartzmann on SERVE, point winners:
# 0     39
# 1     38
# -2    24
# Name: Winner_Point, dtype: int64

# %%
print(name1 + " on SERVE, point winners:")
df[(df["Shot"]==1)&(df["Player"]=="Player")]["Winner_Point"].value_counts()
# Out:
# Alcaraz on SERVE, point winners:
# 1     34
# 0     20
# -1     9
# Name: Winner_Point, dtype: int64

# %%
"""
check server for each serve!
check serve (if out and nb shots > 2 then it s IN) 
synchronize time between video score and file score
for each point:
	compare point winner vs score file
	- find point scored at closest time in file (max -5, +8sec)
	- if found point and error point between both sources:
		if 1 shot only
			if result == out
				result=IN
		if 2+ shots
			correct last shot from losing player => in to OUT
			remove all next shots
	- if no error
		if some earlier shots have OUT, correct them as IN
	- if not found point (+10, -10) and shot1==out or net (only serve)
		if result==in or result==out
			correct to result=out
			remove all next shots
"""
def check_server(df, point_index, df_scores):
    """
    Check if the server is right
    If not, update all shots behind serve
    """
    df_all_shots_for_point = get_all_shots_for_point(df)
    row_serve = df_all_shots_for_point[str(df_all_shots_for_point['Shot'])=="1"]
    row_last_shot = df_all_shots_for_point[df_all_shots_for_point["Shot"]==df_all_shots_for_point["Shot"].max()]
    last_shot_result = row_last_shot.iloc[0]["Result"]
    index_winner = -1
    str_player_last_shot = row_last_shot.iloc[0]["Player"]
    #if ()
    return df

#FOR EACH UNIQUE POINT, set point_winner for all shots of this point
"""df_scores = pd.read_csv(filename_csv.replace("?csv","-scoreok.csv"))
for point_index in df["Point"].unique():
    check_server(df, point_index, df_scores)"""
# Out:
# 'df_scores = pd.read_csv(filename_csv.replace("?csv","-scoreok.csv"))\nfor point_index in df["Point"].unique():\n    check_server(df, point_index, df_scores)'
